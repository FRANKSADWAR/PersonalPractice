# %%
import numpy as np
import pandas as pd

# %%
a = np.array([0,1,2,3,4])

# %%
a[0]
# Out:
# np.int64(0)

# %%
type(a)
# Out:
# numpy.ndarray

# %%
a.dtype
# Out:
# dtype('int64')

# %%
a.size ## NUMBER OF ELEMENTS in the array
# Out:
# 5

# %%
a.ndim
# Out:
# 1

# %%
a.shape
# Out:
# (5,)

# %%
b = np.array([[90.1,21.5,1.2],[12.9,8.5,7.6]])

# %%
b.size
# Out:
# 6

# %%
b.dtype
# Out:
# dtype('float64')

# %%
b.ndim
# Out:
# 2

# %%
b.shape
# Out:
# (2, 3)

# %%
type(a)
# Out:
# numpy.ndarray

# %% [markdown]
# ## Numpy arrays are mutable i.e the elements can be changed after they have been created

# %%
b[0][1] = 51.6

# %%
b
# Out:
# array([[90.1, 51.6,  1.2],
#        [12.9,  8.5,  7.6]])

# %%
a[0] = 99

# %%
a
# Out:
# array([99,  1,  2,  3,  4])

# %%
a[1:4]
# Out:
# array([1, 2, 3])

# %%
u = np.array([1,2])
v = np.array([3,2])

# %%
u * v
# Out:
# array([3, 4])

# %%
np.transpose(u)
# Out:
# array([1, 2])

# %%
x = np.linspace(-2,2,num=9)
y = np.sin(x)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x,y)

# %%
a = np.linspace(0, 2*np.pi, 100)
b = np.sin(a)
plt.plot(a, b)

# %% [markdown]
# #### Matrix multiplication: dot product

# %%
u = np.array([[0,2],[3,0]])
v = np.array([3,5])

# %%
np.dot(u,v)
# Out:
# array([10,  9])

# %%
z = np.array([[2,1],[1,3]])

# %%
p = np.dot(u,z)

# %%
p.shape
# Out:
# (2, 2)

# %%
p
# Out:
# array([[2, 6],
#        [6, 3]])

# %%
p.T
# Out:
# array([[2, 6],
#        [6, 3]])

# %%
p.mean()
# Out:
# np.float64(4.25)

# %%
p[0]
# Out:
# array([2, 6])

# %%
p[1]
# Out:
# array([6, 3])

# %%
p[:,0].reshape(2,1).mean()
# Out:
# np.float64(4.0)
